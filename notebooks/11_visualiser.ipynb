# %% [markdown]
# # Overlaying the network onto the MNI brain

# %% [markdown]
# ### Import

# %%
from config import *
from src.viz import viz
from src.data import subjects

# %% [markdown]
# ### Visualization Function
#
# In the below function, the subjects argument can be either a list of subjects or a number.
# If it's a number, for example n, the function will visualise n random control subjects and n random AD subjects.

# %%
viz.brain_viz(['CN','AD'],denoising_strategy = '36p',
              correlation_type = 'pearson',subs =1,
              density = .005, method = '3d')

# %% [markdown]
# You can also visualize a network from a directory.
# for example:

# %%
path = rootdir + '/data/04_correlations/corr-pearson/ds-36p/sub-006S4515_ds-36p_corr-pearson.npy'
title = "example"

# %%
viz.brain_viz_from_path(path = path , title = title, density = .005, method = '3d')

# %%
import numpy as np
M = np.load(path)
# Out:
# (360, 360)

# %%
viz.brain_viz_from_path(cm = M , title = title, density = .005, method = '2d')
# Out:
# example

# %%
viz.brain_viz_nodes(nodes=[1,2],title='nodes:',method='2d',node_size=[1,1])
# Out:
# nodes:
