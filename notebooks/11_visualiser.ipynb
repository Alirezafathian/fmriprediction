# %% [markdown]
# |<font size="5">Overlaying the network onto the MNI brain</font>|
# |--------------------------------------------------------------|

# %% [markdown]
# ### Import

# %%
from config import *
from src.viz import viz
from src.data import subjects

# %% [markdown]
# ### visualization Function
#
# In the below function, the subjects argument can be either a list of subjects or a number.
# If it's a number, for example n, the function will visualise n random control subjects and n random AD subjects.

# %%
viz.brain_vis(['CN','AD'],denoising_strategy = '36p',
              correlation_type = 'pearson',subs =1,
              density = .005, method = '2d')
# Out:
# /home/alireza/Thesis/THSenv/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/alireza/Thesis/THSenv/lib/python3.6/site-packages/numpy/core/_methods.py:154: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# Top 0.500% Edges,CN Subject: 116S4453, DS: 36p, CT: pearson
# Top 0.500% Edges,AD Subject: 130S4660, DS: 36p, CT: pearson
