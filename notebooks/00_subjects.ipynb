# %% [markdown]
# |<font size="5">Subjects</font>|
# |------------------------------|

# %%
from src.data import subjects
print(subjects.results)
# Out:
# ...
#
# List of subjects to be downloaded:
# ['114S2392']
# ...
#
# List of subjects to be converted into BIDs format:
# []
# ...
#
# List of subjects to be preprocessed:
# ['067S4072', '067S4184', '067S2301', '067S4212', '094S2238', '068S4067']
# ...
#
# List of subjects to be denoised:
# []
# ...
#
# List of subjects to construct correlation matrix:
# []
# ...
#
# List of subjects to construct adjacency matrix:
# []
# ...
#
# List of subjects to compute network measures:
# [['014S2308'], [['003S4354', '9p', 'userdefined-0.050'], ['003S4354', '36p', 'gce'], ['003S4354', '36p', 'userdefined-0.050'], ['003S4354', '36pscrubbed', 'gce'], ['003S4354', '36pscrubbed', 'userdefined-0.050']]]
# ...
#
# List of subjects to do single subject network analysis:
# ...

# %%
l1 = ['012S4987','002S4473','011S4547','011S4893','012S4188','014S2308','037S4706','041S4513','041S4974','067S2301','067S4072','067S4184','067S4212','068S2184','068S2315','068S4067','068S4431','082S2121','094S2201','094S2238','114S2392','137S4299','137S4351','137S4536']
aa=set(subjects.to_preprocess).difference(set(l1)) #CNs
print(aa,len(aa))
# Out:
# {'006S4363', '037S4030', '006S4713', '036S4715', '002S4746', '037S4214', '002S4654', '006S4346', '012S4094', '036S4538', '006S4515', '068S4061', '035S4414', '036S4430', '002S4251', '941S4187'} 16

# %%
:
sub-067S2301
sub-067S4072
sub-067S4184
sub-067S4212

# %%
a = ['094S2238', '137S4536', '137S4351', '037S4706', '012S4987', '068S4067', '041S4974', '082S2121', '041S4513', '068S2184', '094S2201', '012S4188', '068S4431', '137S4299', '002S4473', '068S2315', '014S2308', '011S4893', '011S4547']
len(a)
# Out:
# 19

# %%
len(['137S4351', '068S4067', '067S2301', '012S4987', '012S4188', '137S4299', '067S4072', '014S2308', '011S4547', '037S4706', '068S4431', '068S2184', '068S2315', '094S2238', '067S4212', '041S4974', '002S4473', '094S2201', '011S4893', '041S4513', '082S2121', '137S4536', '067S4184'])
# Out:
# 23
