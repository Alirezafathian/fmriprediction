# %% [markdown]
# # Feature Selection

# %%
from config import *
ds = '36p' # Denoising Strategy:
ct = 'pearson' #Correlation Type
negative_corr = True
tm = 'gce' # Thresholding Method:
           # It could be 'GCE' or 'user_defined'
tv = 0.05  # Thresholding Value, For user defined tm

# %% [markdown]
# ### Import

# %%
from src.data import subjects
import numpy as np
import pandas as pd
import glob,os
from IPython.display import display
from skfeature.function.similarity_based import fisher_score
import matplotlib.pyplot as plt
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn import svm
import collections
from src.viz import viz
import matplotlib.ticker as ticker
import src.group_level_analysis.group_level_analysis as gla
import networkx as nx

# %% [markdown]
# ### Read Data

# %%
#all_sub_list = subjects.to_group_level_analysis[0]
all_sub_list = list(subjects.subjects['all']['participant_id'].values)
all_subjects = subjects.subjects['all'][subjects.subjects['all']['participant_id'].isin(all_sub_list)]

subjects_list = {}
for sg in subjects_groups:
    subjects_list[sg] = all_subjects.where(all_subjects.group==sg).dropna()
    print('\n%d %s subjects are included'%(len(subjects_list[sg]),sg))
    display(subjects_list[sg])
    subjects_list[sg] = subjects_list[sg].participant_id.tolist()
# Out:
# 24 CN subjects are included
#    group participant_id sex   age
# 0     CN       003S4288   F  78.4
# 1     CN       011S0021   F  84.9
# 2     CN       020S6185   M  82.7
# 3     CN       023S1190   F  87.4
# 4     CN       035S6160   M  60.7
# 5     CN       036S6189   F  69.6
# 6     CN       037S4028   F  70.7
# 7     CN       041S4200   F  76.4
# 8     CN       041S6159   M  76.3
# 9     CN       041S6192   F  83.3
# 10    CN       094S4649   M  71.2
# 11    CN       114S0416   F  87.2
# 12    CN       114S6063   F  74.3
# 13    CN       116S6119   F  67.1
# 14    CN       168S6098   M  63.4
# 15    CN       168S6085   F  55.8
# 16    CN       168S6131   F  68.3
# 17    CN       941S6094   F  69.6
# 18    CN       116S4453   M  72.0
# 19    CN       033S4176   M  90.5
# 20    CN       002S4262   F  74.0
# 21    CN       002S4225   M  70.0
# 22    CN       031S4032   F  70.0
# 23    CN       018S4313   F  78.0
# 24 EMCI subjects are included
#    group participant_id sex   age
# 24  EMCI       012S4987   M  69.0
# 25  EMCI       002S4473   M  79.9
# 26  EMCI       011S4547   M  82.8
# 27  EMCI       011S4893   F  73.4
# 28  EMCI       012S4188   M  83.2
# 29  EMCI       014S2308   M  81.4
# 30  EMCI       037S4706   M  66.2
# 31  EMCI       041S4513   M  66.4
# 32  EMCI       041S4974   M  78.4
# 33  EMCI       068S2184   F  87.4
# 34  EMCI       068S2315   F  74.9
# 35  EMCI       068S4067   M  71.2
# 36  EMCI       068S4431   M  79.8
# 37  EMCI       082S2121   F  75.2
# 38  EMCI       094S2201   F  70.5
# 39  EMCI       094S2238   M  75.6
# 40  EMCI       002S2010   F  64.0
# 41  EMCI       002S4237   F  81.0
# 42  EMCI       002S2073   F  63.0
# 43  EMCI       002S4799   M  68.0
# 44  EMCI       002S2043   F  72.0
# 45  EMCI       137S4299   F  82.9
# 46  EMCI       137S4351   F  73.8
# 47  EMCI       137S4536   F  83.6
# 24 LMCI subjects are included
#    group participant_id sex   age
# 48  LMCI       002S4171   M  69.0
# 49  LMCI       002S4219   F  80.0
# 50  LMCI       002S4229   M  66.0
# 51  LMCI       002S4251   M  72.0
# 52  LMCI       002S4654   F  75.0
# 53  LMCI       002S4746   F  72.0
# 54  LMCI       003S4354   M  81.0
# 55  LMCI       006S4346   M  71.0
# 56  LMCI       006S4363   F  74.0
# 57  LMCI       006S4515   M  75.0
# 58  LMCI       006S4713   M  71.0
# 59  LMCI       006S4960   M  60.0
# 60  LMCI       012S4094   F  60.0
# 61  LMCI       013S4236   F  58.0
# 62  LMCI       013S4395   F  73.0
# 63  LMCI       035S4414   F  66.0
# 64  LMCI       036S4430   M  86.0
# 65  LMCI       036S4538   F  85.0
# 66  LMCI       036S4715   F  62.0
# 67  LMCI       037S4030   F  75.0
# 68  LMCI       037S4214   M  80.0
# 69  LMCI       041S4510   F  72.0
# 70  LMCI       068S4061   F  71.0
# 71  LMCI       941S4187   M  68.0
# 24 AD subjects are included
#    group participant_id sex   age
# 72    AD       002S5018   M  73.4
# 73    AD       006S4153   M  81.5
# 74    AD       006S4867   M  75.7
# 75    AD       013S5071   M  76.4
# 76    AD       018S4696   F  73.3
# 77    AD       018S4733   M  75.4
# 78    AD       018S5074   F  74.9
# 79    AD       019S4252   F  86.8
# 80    AD       019S4477   F  82.4
# 81    AD       019S4549   M  79.4
# 82    AD       019S5012   M  76.4
# 83    AD       053S5070   M  72.4
# 84    AD       053S5208   M  68.8
# 85    AD       100S5106   M  74.3
# 86    AD       130S4589   F  75.2
# 87    AD       130S4641   F  73.9
# 88    AD       130S4660   F  77.3
# 89    AD       130S4730   F  81.2
# 90    AD       130S4971   M  77.1
# 91    AD       130S4984   F  73.2
# 92    AD       130S4990   F  75.7
# 93    AD       130S5059   M  72.8
# 94    AD       130S5231   F  74.4
# 95    AD       136S4993   F  71.9

# %%
str_loc    = ['loc_'  + ds for ds in denoising_strategies]
str_glob   = ['glob_' + ds for ds in denoising_strategies]
strlist    = str_loc.copy()
strlist.extend(str_glob)

# %%
if tm=='userdefined':
    tm = '%s-%.3f'%(tm,tv)
sgn = 'positive'
if negative_corr:
    sgn = 'negative'
if ct == 'glasso':
    sgn = ''

# %%
norm = ""
if normalize_measures:
    norm="_norm"

directoies = {}
for ds in denoising_strategies:
    dirc = '%s/data/06_network_measures/positive/tm-%s/corr-%s/ds-%s/'%(rootdir,tm,ct,ds)
    if negative_corr:
        dirc = '%s/data/06_network_measures/negative/tm-%s/corr-%s/ds-%s/'%(rootdir,tm,ct,ds)

    lc  = 'loc_'  + ds
    glb = 'glob_' + ds
    directoies[glb]    = glob.glob("%s/*/*global_measures_giant_component.csv"%(dirc))
    directoies[lc] = glob.glob("%s/*/*local_measures_giant_component*%s*.csv"%(dirc,norm))

# %%
measures = {}
measures['all'] = {}

for sg in subjects_groups: 
    measures[sg]  = {}

for i in strlist:
    measures['all'][str(i)] = {}
    for sg in subjects_groups: 
        measures[sg][str(i)]  = {}
    for sub in directoies[str(i)]:
        id = str(sub.split("/sub-")[1].split('/sub-')[0]) 
        measures['all'][str(i)][id] = pd.read_csv(sub, sep='\t')
        measures['all'][str(i)][id] = measures['all'][str(i)][id].drop(['Unnamed: 0'], axis=1)
        if 'loc' in str(i):
            measures['all'][str(i)][id] = measures['all'][str(i)][id].set_index('ID')
        for sg in subjects_groups: 

            if id in subjects_list[sg]:
                measures[sg][str(i)][id] = pd.read_csv(sub, sep='\t')
                measures[sg][str(i)][id] = measures[sg][str(i)][id].drop(['Unnamed: 0'], axis=1)
                if 'loc' in str(i):
                    measures[sg][str(i)][id] = measures[sg][str(i)][id].set_index('ID')

# %%
# measures variable structure:
#
#    measures
#    │
#    ├── group 1
#    │   ├── denoising strategie 1- global measures
#    │   │   └── group 1 subjects
#    │   ├── denoising strategie 1- local measures
#    │   │   └── group 1 subjects
#    │   ├── denoising strategie 2- global measures
#    │   │   └── group 1 subjects
#    │   ├── denoising strategie 2- local measures
#    │   │   └── group 1 subjects
#    │   ├── ...
#    │   │
#    │   └── denoising strategie n- local measures
#    │       └── group 1 subjects
#    │   
#    ├── ...
#    │
#    └── last group
#        ├── denoising strategie 1- global measures
#        │   └── last group subjects
#        ├── denoising strategie 1- local measures
#        │   └── last group subjects
#        ├── denoising strategie 2- global measures
#        │   └── last group subjects
#        ├── denoising strategie 2- local measures
#        │   └── last group subjects
#        ├── ...
#        │
#        └── denoising strategie n- local measures
#            └── last group subject

# %%
measures['all']['loc_36p']['036S4715']
# Out:
#        degree  eccentricity  betweenness  com_betweenness  eigenvector  \
# ID
# 0    0.344538           0.0     0.083707         0.246383     0.407932
# 1    0.638655           0.0     0.325329         0.610381     0.716206
# 2    0.218487           0.0     0.034414         0.148549     0.299553
# 3    0.344538           0.0     0.057462         0.332313     0.492592
# 4    0.411765           0.0     0.072851         0.445095     0.590813
# ..        ...           ...          ...              ...          ...
# 355  0.378151           0.0     0.112114         0.235535     0.393497
# 356  0.663866           0.0     0.447712         0.532918     0.653298
# 357  0.235294           0.0     0.049223         0.110558     0.246942
# 358  0.260504           0.0     0.042327         0.198449     0.358488
# 359  0.554622           0.0     0.174114         0.534520     0.660976
#
#          katz  closeness  current_flow_closeness      load  clustering_coef  \
# ID
# 0    0.332725   0.493564                0.673175  0.085442         0.145698
# 1    0.558224   0.728992                0.873433  0.323842         0.070009
# 2    0.691444   0.389764                0.523674  0.035329         0.120968
# 3    0.444849   0.598163                0.674821  0.057117         0.222017
# 4    0.547072   0.639043                0.734445  0.071304         0.252525
# ..        ...        ...                     ...       ...              ...
# 355  0.478399   0.512327                0.703894  0.111039         0.094118
# 356  0.702685   0.728992                0.884753  0.454350         0.119748
# 357  0.498399   0.428159                0.546030  0.051493         0.173797
# 358  0.603237   0.435265                0.581105  0.042953         0.123874
# 359  0.495915   0.639043                0.830124  0.172747         0.029343
#
#      pagerank  subgraph  harmonic  strength
# ID
# 0    0.327502  0.196502  0.466403  0.323384
# 1    0.622030  0.538293  0.719368  0.259601
# 2    0.204478  0.115876  0.349802  0.520886
# 3    0.316964  0.273794  0.519763  0.630156
# 4    0.377533  0.379192  0.571146  0.619616
# ..        ...       ...       ...       ...
# 355  0.366938  0.184578  0.492095  0.426082
# 356  0.658413  0.455018  0.731225  0.049510
# 357  0.226867  0.084150  0.379447  0.461898
# 358  0.241460  0.157164  0.395257  0.483332
# 359  0.524599  0.464802  0.638340  0.336758
#
# [359 rows x 14 columns]

# %% [markdown]
# ### Finding out nodes that exist in all networks

# %%
print('the number of nodes appeared in the giant components of all subjects:\n') 
intersect = {}
for i in str_loc:
    intersect[i] = list(range(360))
for i in str_loc:
    for sub in measures['all'][i]:
        a = list(measures['all'][i][sub].index)
        intersect[i] = list(set(intersect[i]) & set(a))
    name = i.split('loc_')[1]
    print('\t%d out of 360 nodes for networks with %s thresholding method.'
          %(len(intersect[i]),name))

    #removing nodes
    for sub in measures['all'][i]:
        measures['all'][str(i)][sub] = measures['all'][str(i)][sub].loc[measures['all'][str(i)][sub].index.isin(intersect[i])]
# Out:
# the number of nodes appeared in the giant components of all subjects:
#
# 	356 out of 360 nodes for networks with 36p thresholding method.

# %% [markdown]
# ### Constructing Feature Matrix
#
# It's a N*M matrix, where:
#
# \begin{equation*}
# N   =  Number \: of \: Smples; \\
# M   =  (Number \: of \: Local \: Measures \: * \: Number \: of \: Nodes) \: + \: Number \: of \: Global \: Measures
# \end{equation*}

# %%
14*359+10
# Out:
# 5036

# %%
features = pd.DataFrame({})
s = []
for sub in measures['all']['loc_'+ds]:
    loc  = measures['all']['loc_'+ds][sub].stack().to_frame()
    glob = measures['all']['glob_'+ds][sub].drop(
        columns=['center', 'periphery'])
    fea  = pd.concat([loc,glob.transpose()],axis=0)
    s.append(sub)
    try:
        features = pd.concat([features,fea],axis=1)
    except NameError:
        features = fea.copy()

features.columns = s
features = features.transpose().sort_index(axis = 0)
features.index.name = 'participant_id'

# %%
labels = all_subjects[['group','participant_id']].sort_values(by=['participant_id'])
labels = labels.set_index('participant_id')
for g in range(len(subjects_groups)):
    labels = labels.replace(subjects_groups[g],g+1)

# %%
features_np = features.values
labels_np   = labels.values[:,0]

# %% [markdown]
# ### Feature Selection Using Fisher Algorithm

# %%
score = fisher_score.fisher_score(features_np, labels_np)
idx   = fisher_score.feature_ranking(score)

# %% [markdown]
# Selecting the top 50% of features

# %%
fisher_features    = features.iloc[:, idx[:int(len(idx)/2)]]
fisher_features_np = fisher_features.values

# %% [markdown]
# Selecting effective nodes and measures based on Fisher algorithm

# %%
fisher_features30          = features.iloc[:, idx[:30]]
fisher_features_names30    = list(fisher_features30.T.index) 
fisher_features_names30    = [ffn for ffn in fisher_features_names30 if type(ffn)!=str]
fisher_features_nodes30    = [ffn[0] for ffn in fisher_features_names30]
fisher_features_measures30 = [ffn[1] for ffn in fisher_features_names30]
fisher_features_measures30.sort()
fisher_features_nodes30.sort()
counter_measures30=collections.Counter(fisher_features_measures30)
counter_nodes30=collections.Counter(fisher_features_nodes30)

# %%
fig, ax = plt.subplots(figsize=(30,5))
plt.scatter(*zip(*[(str(a[0]),a[1]) for a in counter_nodes30.most_common(len(set(fisher_features_nodes30)))]))
plt.xticks(np.arange(0, len(set(fisher_features_nodes30)), step=1))
plt.legend(['all'])
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:.0f}"))
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
plt.show()

fNodes301=counter_nodes30.most_common(30)
nd301 = [a[0] for a in fNodes301]
ns301 = [a[1] for a in fNodes301]
viz.brain_viz_nodes(nodes=nd301,
                    title=
                    "\t%s Fisher Nodes:\n\t%s"
                    %(30,counter_nodes30.most_common(30)),
                    method='2d',node_size = ns301)
# Out:
# /home/alireza/Thesis/THSenv/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/alireza/Thesis/THSenv/lib/python3.6/site-packages/numpy/core/_methods.py:154: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# 	30 Fisher Nodes:
# 	[(199, 5), (340, 5), (112, 2), (123, 2), (213, 2), (224, 2), (239, 2), (276, 2), (69, 1), (70, 1), (87, 1), (156, 1), (162, 1), (249, 1), (283, 1), (330, 1)]

# %%
plt.figure(figsize=(20,5))
plt.scatter(*zip(*counter_measures30.most_common(14)))
plt.xticks(np.arange(0, 14, step=1))
plt.show()

# %%
print(counter_measures30.most_common(14),'\n\n',counter_nodes30.most_common(360))
# Out:
# [('closeness', 8), ('harmonic', 6), ('strength', 5), ('com_betweenness', 3), ('eigenvector', 3), ('subgraph', 2), ('betweenness', 1), ('current_flow_closeness', 1), ('load', 1)]
#
#  [(199, 5), (340, 5), (112, 2), (123, 2), (213, 2), (224, 2), (239, 2), (276, 2), (69, 1), (70, 1), (87, 1), (156, 1), (162, 1), (249, 1), (283, 1), (330, 1)]

# %%
fisher_features4          = features.iloc[:, idx[:int(len(idx)/4)]]
fisher_features_names4    = list(fisher_features4.T.index) 
fisher_features_names4    = [ffn for ffn in fisher_features_names4 if type(ffn)!=str]
fisher_features_nodes4    = [ffn[0] for ffn in fisher_features_names4]
fisher_features_measures4 = [ffn[1] for ffn in fisher_features_names4]
fisher_features_measures4.sort()
fisher_features_nodes4.sort()
counter_measures4=collections.Counter(fisher_features_measures4)
counter_nodes4=collections.Counter(fisher_features_nodes4)

# %%
a1 = 66
a2 = 20
fig, ax = plt.subplots(figsize=(20,5))
plt.scatter(*zip(*[(str(a[0]),a[1]) for a in counter_nodes4.most_common(len(set(fisher_features_nodes4)))]))
plt.scatter(*zip(*[(str(a[0]),a[1]) for a in counter_nodes4.most_common(a1)]))
plt.scatter(*zip(*[(str(a[0]),a[1]) for a in counter_nodes4.most_common(a2)]))
plt.xticks(np.arange(0, len(set(fisher_features_nodes4)), step=1))
plt.legend(['all',a1,a2])
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:.0f}"))
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
plt.show()

fNodes41=counter_nodes4.most_common(a1)
fNodes42=counter_nodes4.most_common(a2)
nd42 = [a[0] for a in fNodes42]
ns42 = [a[1] for a in fNodes42]
viz.brain_viz_nodes(nodes=nd42,title="\t%s Fisher Nodes:\n\t%s"%(a2,counter_nodes4.most_common(a2)),method='2d',node_size = ns42)
plt.show()
nd41 = [a[0] for a in fNodes41]
ns41 = [a[1] for a in fNodes41]
viz.brain_viz_nodes(nodes=nd41,title="\t%s Fisher Nodes:\n\t%s"%(a1,counter_nodes4.most_common(a1)),method='2d',node_size = ns41)
enodes4_top = [np.array(counter_nodes4.most_common(a2)),'fisher-%d'%a2]
enodes4 = [np.array(counter_nodes4.most_common(a1)),'fisher-%d'%a1]
# Out:
# 	20 Fisher Nodes:
# 	[(100, 12), (162, 12), (167, 12), (68, 11), (72, 11), (101, 11), (102, 11), (112, 11), (114, 11), (123, 11), (156, 11), (174, 11), (200, 11), (239, 11), (246, 11), (276, 11), (303, 11), (330, 11), (335, 11), (357, 11)]
# 	66 Fisher Nodes:
# 	[(100, 12), (162, 12), (167, 12), (68, 11), (72, 11), (101, 11), (102, 11), (112, 11), (114, 11), (123, 11), (156, 11), (174, 11), (200, 11), (239, 11), (246, 11), (276, 11), (303, 11), (330, 11), (335, 11), (357, 11), (25, 10), (37, 10), (49, 10), (59, 10), (66, 10), (98, 10), (99, 10), (122, 10), (172, 10), (173, 10), (199, 10), (213, 10), (236, 10), (275, 10), (328, 10), (340, 10), (348, 10), (352, 10), (20, 9), (61, 9), (82, 9), (132, 9), (155, 9), (196, 9), (198, 9), (208, 9), (211, 9), (238, 9), (248, 9), (286, 9), (307, 9), (312, 9), (17, 8), (23, 8), (26, 8), (31, 8), (45, 8), (52, 8), (87, 8), (92, 8), (125, 8), (209, 8), (214, 8), (218, 8), (224, 8), (297, 8)]

# %%
plt.figure(figsize=(20,5))
plt.scatter(*zip(*counter_measures4.most_common(14)))
plt.xticks(np.arange(0, 14, step=1))
plt.show()
print(counter_measures4.most_common(14))
# Out:
# [('strength', 125), ('closeness', 117), ('harmonic', 110), ('eigenvector', 109), ('current_flow_closeness', 104), ('com_betweenness', 103), ('subgraph', 101), ('degree', 88), ('betweenness', 84), ('load', 82), ('pagerank', 82), ('eccentricity', 61), ('katz', 41), ('clustering_coef', 37)]

# %% [markdown]
# ### Feature Selection Using FSFS
#
# Aplying FSFS algorithm on the first half of sorted features by the fisher score

# %% [markdown]
# #### classifier: LinearRegression

# %%
sfsLinReg = SFS(LinearRegression(),
                k_features=(35),
                forward=True,
                floating=False,
                scoring = 'r2',
                cv = 0)

# %%
sfsLinReg.fit(fisher_features_np, labels_np,tuple(fisher_features.columns))
sfsLinReg.k_feature_names_
# Out:
# ((239, 'closeness'),
#  (224, 'closeness'),
#  (87, 'strength'),
#  (101, 'betweenness'),
#  (68, 'strength'),
#  (98, 'load'),
#  (108, 'eccentricity'),
#  (14, 'clustering_coef'),
#  (357, 'current_flow_closeness'),
#  (130, 'betweenness'),
#  (304, 'clustering_coef'),
#  (141, 'eccentricity'),
#  (76, 'load'),
#  (51, 'clustering_coef'),
#  (281, 'subgraph'),
#  (211, 'clustering_coef'),
#  (180, 'clustering_coef'),
#  (160, 'closeness'),
#  (50, 'harmonic'),
#  (51, 'subgraph'),
#  (348, 'closeness'),
#  (85, 'clustering_coef'),
#  (145, 'load'),
#  (217, 'eccentricity'),
#  (159, 'eigenvector'),
#  (222, 'strength'),
#  (314, 'current_flow_closeness'),
#  (268, 'betweenness'),
#  (99, 'closeness'),
#  (203, 'clustering_coef'),
#  (154, 'harmonic'),
#  (356, 'pagerank'),
#  (80, 'subgraph'),
#  (65, 'load'),
#  (10, 'clustering_coef'))

# %%
figLR = plot_sfs(sfsLinReg.get_metric_dict(), kind='std_dev')
plt.title('Sequential Forward Selection (w. StdErr)')
plt.grid()
plt.show()
# Out:
# /home/alireza/Thesis/THSenv/lib/python3.6/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/alireza/Thesis/THSenv/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
sfsLinReg.get_metric_dict()
# Out:
# {1: {'feature_idx': (2,),
#   'cv_scores': array([0.21669313]),
#   'avg_score': 0.21669313464215068,
#   'feature_names': ((224, 'closeness'),),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  2: {'feature_idx': (2, 6),
#   'cv_scores': array([0.34815992]),
#   'avg_score': 0.34815992004447904,
#   'feature_names': ((224, 'closeness'), (87, 'strength')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  3: {'feature_idx': (0, 2, 6),
#   'cv_scores': array([0.44579571]),
#   'avg_score': 0.4457957052743945,
#   'feature_names': ((239, 'closeness'), (224, 'closeness'), (87, 'strength')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  4: {'feature_idx': (0, 2, 6, 90),
#   'cv_scores': array([0.51375672]),
#   'avg_score': 0.5137567171539326,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  5: {'feature_idx': (0, 2, 6, 90, 485),
#   'cv_scores': array([0.57420373]),
#   'avg_score': 0.574203727434824,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (108, 'eccentricity')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  6: {'feature_idx': (0, 2, 6, 90, 485, 929),
#   'cv_scores': array([0.62999986]),
#   'avg_score': 0.6299998645499071,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (108, 'eccentricity'),
#    (76, 'load')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  7: {'feature_idx': (0, 2, 6, 90, 485, 929, 1295),
#   'cv_scores': array([0.67841102]),
#   'avg_score': 0.6784110158871153,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (108, 'eccentricity'),
#    (76, 'load'),
#    (348, 'closeness')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  8: {'feature_idx': (0, 2, 6, 90, 485, 929, 1130, 1295),
#   'cv_scores': array([0.71762101]),
#   'avg_score': 0.7176210078051974,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (108, 'eccentricity'),
#    (76, 'load'),
#    (211, 'clustering_coef'),
#    (348, 'closeness')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  9: {'feature_idx': (0, 2, 6, 90, 485, 929, 1130, 1197, 1295),
#   'cv_scores': array([0.75888902]),
#   'avg_score': 0.7588890164585045,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (108, 'eccentricity'),
#    (76, 'load'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (348, 'closeness')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  10: {'feature_idx': (0, 2, 6, 90, 485, 929, 1130, 1197, 1220, 1295),
#   'cv_scores': array([0.78680177]),
#   'avg_score': 0.7868017681740268,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (108, 'eccentricity'),
#    (76, 'load'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (348, 'closeness')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  11: {'feature_idx': (0, 2, 6, 90, 485, 518, 929, 1130, 1197, 1220, 1295),
#   'cv_scores': array([0.81394405]),
#   'avg_score': 0.8139440512512652,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (108, 'eccentricity'),
#    (357, 'current_flow_closeness'),
#    (76, 'load'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (348, 'closeness')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  12: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    485,
#    518,
#    929,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295),
#   'cv_scores': array([0.84561295]),
#   'avg_score': 0.8456129477770415,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (108, 'eccentricity'),
#    (357, 'current_flow_closeness'),
#    (76, 'load'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  13: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    485,
#    518,
#    929,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295),
#   'cv_scores': array([0.86914207]),
#   'avg_score': 0.8691420703000152,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (108, 'eccentricity'),
#    (357, 'current_flow_closeness'),
#    (76, 'load'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  14: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    485,
#    518,
#    929,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295),
#   'cv_scores': array([0.88238508]),
#   'avg_score': 0.8823850801888901,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (108, 'eccentricity'),
#    (357, 'current_flow_closeness'),
#    (76, 'load'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  15: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    485,
#    518,
#    929,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295,
#    2446),
#   'cv_scores': array([0.89541609]),
#   'avg_score': 0.8954160879149218,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (108, 'eccentricity'),
#    (357, 'current_flow_closeness'),
#    (76, 'load'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness'),
#    (65, 'load')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  16: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    485,
#    518,
#    929,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295,
#    2122,
#    2446),
#   'cv_scores': array([0.90600363]),
#   'avg_score': 0.9060036326062064,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (108, 'eccentricity'),
#    (357, 'current_flow_closeness'),
#    (76, 'load'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness'),
#    (154, 'harmonic'),
#    (65, 'load')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  17: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    485,
#    518,
#    654,
#    929,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295,
#    2122,
#    2446),
#   'cv_scores': array([0.91715683]),
#   'avg_score': 0.917156832094436,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (108, 'eccentricity'),
#    (357, 'current_flow_closeness'),
#    (130, 'betweenness'),
#    (76, 'load'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness'),
#    (154, 'harmonic'),
#    (65, 'load')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  18: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    485,
#    518,
#    654,
#    729,
#    929,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295,
#    2122,
#    2446),
#   'cv_scores': array([0.92422954]),
#   'avg_score': 0.9242295449394938,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (108, 'eccentricity'),
#    (357, 'current_flow_closeness'),
#    (130, 'betweenness'),
#    (304, 'clustering_coef'),
#    (76, 'load'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness'),
#    (154, 'harmonic'),
#    (65, 'load')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  19: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    485,
#    518,
#    654,
#    729,
#    929,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295,
#    1919,
#    2122,
#    2446),
#   'cv_scores': array([0.93137672]),
#   'avg_score': 0.9313767174570359,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (108, 'eccentricity'),
#    (357, 'current_flow_closeness'),
#    (130, 'betweenness'),
#    (304, 'clustering_coef'),
#    (76, 'load'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness'),
#    (268, 'betweenness'),
#    (154, 'harmonic'),
#    (65, 'load')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  20: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    485,
#    518,
#    654,
#    729,
#    929,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295,
#    1919,
#    2013,
#    2122,
#    2446),
#   'cv_scores': array([0.93858796]),
#   'avg_score': 0.9385879634347384,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (108, 'eccentricity'),
#    (357, 'current_flow_closeness'),
#    (130, 'betweenness'),
#    (304, 'clustering_coef'),
#    (76, 'load'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness'),
#    (268, 'betweenness'),
#    (203, 'clustering_coef'),
#    (154, 'harmonic'),
#    (65, 'load')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  21: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    485,
#    518,
#    654,
#    729,
#    756,
#    929,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295,
#    1919,
#    2013,
#    2122,
#    2446),
#   'cv_scores': array([0.94473815]),
#   'avg_score': 0.9447381541447152,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (108, 'eccentricity'),
#    (357, 'current_flow_closeness'),
#    (130, 'betweenness'),
#    (304, 'clustering_coef'),
#    (141, 'eccentricity'),
#    (76, 'load'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness'),
#    (268, 'betweenness'),
#    (203, 'clustering_coef'),
#    (154, 'harmonic'),
#    (65, 'load')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  22: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    485,
#    518,
#    654,
#    729,
#    756,
#    929,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295,
#    1510,
#    1919,
#    2013,
#    2122,
#    2446),
#   'cv_scores': array([0.94956773]),
#   'avg_score': 0.9495677278676596,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (108, 'eccentricity'),
#    (357, 'current_flow_closeness'),
#    (130, 'betweenness'),
#    (304, 'clustering_coef'),
#    (141, 'eccentricity'),
#    (76, 'load'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness'),
#    (85, 'clustering_coef'),
#    (268, 'betweenness'),
#    (203, 'clustering_coef'),
#    (154, 'harmonic'),
#    (65, 'load')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  23: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    485,
#    518,
#    654,
#    729,
#    756,
#    929,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295,
#    1510,
#    1919,
#    2013,
#    2122,
#    2400,
#    2446),
#   'cv_scores': array([0.95464963]),
#   'avg_score': 0.9546496344308779,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (108, 'eccentricity'),
#    (357, 'current_flow_closeness'),
#    (130, 'betweenness'),
#    (304, 'clustering_coef'),
#    (141, 'eccentricity'),
#    (76, 'load'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness'),
#    (85, 'clustering_coef'),
#    (268, 'betweenness'),
#    (203, 'clustering_coef'),
#    (154, 'harmonic'),
#    (80, 'subgraph'),
#    (65, 'load')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  24: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    485,
#    518,
#    654,
#    729,
#    756,
#    929,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295,
#    1510,
#    1919,
#    2013,
#    2122,
#    2400,
#    2446,
#    2471),
#   'cv_scores': array([0.96095022]),
#   'avg_score': 0.9609502153273894,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (108, 'eccentricity'),
#    (357, 'current_flow_closeness'),
#    (130, 'betweenness'),
#    (304, 'clustering_coef'),
#    (141, 'eccentricity'),
#    (76, 'load'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness'),
#    (85, 'clustering_coef'),
#    (268, 'betweenness'),
#    (203, 'clustering_coef'),
#    (154, 'harmonic'),
#    (80, 'subgraph'),
#    (65, 'load'),
#    (10, 'clustering_coef')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  25: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    282,
#    485,
#    518,
#    654,
#    729,
#    756,
#    929,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295,
#    1510,
#    1919,
#    2013,
#    2122,
#    2400,
#    2446,
#    2471),
#   'cv_scores': array([0.96620629]),
#   'avg_score': 0.9662062875874516,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (98, 'load'),
#    (108, 'eccentricity'),
#    (357, 'current_flow_closeness'),
#    (130, 'betweenness'),
#    (304, 'clustering_coef'),
#    (141, 'eccentricity'),
#    (76, 'load'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness'),
#    (85, 'clustering_coef'),
#    (268, 'betweenness'),
#    (203, 'clustering_coef'),
#    (154, 'harmonic'),
#    (80, 'subgraph'),
#    (65, 'load'),
#    (10, 'clustering_coef')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  26: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    282,
#    485,
#    518,
#    654,
#    729,
#    756,
#    929,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295,
#    1510,
#    1798,
#    1919,
#    2013,
#    2122,
#    2400,
#    2446,
#    2471),
#   'cv_scores': array([0.97115859]),
#   'avg_score': 0.9711585941282839,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (98, 'load'),
#    (108, 'eccentricity'),
#    (357, 'current_flow_closeness'),
#    (130, 'betweenness'),
#    (304, 'clustering_coef'),
#    (141, 'eccentricity'),
#    (76, 'load'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness'),
#    (85, 'clustering_coef'),
#    (159, 'eigenvector'),
#    (268, 'betweenness'),
#    (203, 'clustering_coef'),
#    (154, 'harmonic'),
#    (80, 'subgraph'),
#    (65, 'load'),
#    (10, 'clustering_coef')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  27: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    282,
#    485,
#    507,
#    518,
#    654,
#    729,
#    756,
#    929,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295,
#    1510,
#    1798,
#    1919,
#    2013,
#    2122,
#    2400,
#    2446,
#    2471),
#   'cv_scores': array([0.97438227]),
#   'avg_score': 0.9743822732492371,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (98, 'load'),
#    (108, 'eccentricity'),
#    (14, 'clustering_coef'),
#    (357, 'current_flow_closeness'),
#    (130, 'betweenness'),
#    (304, 'clustering_coef'),
#    (141, 'eccentricity'),
#    (76, 'load'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness'),
#    (85, 'clustering_coef'),
#    (159, 'eigenvector'),
#    (268, 'betweenness'),
#    (203, 'clustering_coef'),
#    (154, 'harmonic'),
#    (80, 'subgraph'),
#    (65, 'load'),
#    (10, 'clustering_coef')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  28: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    282,
#    485,
#    507,
#    518,
#    654,
#    729,
#    756,
#    929,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295,
#    1510,
#    1615,
#    1798,
#    1919,
#    2013,
#    2122,
#    2400,
#    2446,
#    2471),
#   'cv_scores': array([0.97791156]),
#   'avg_score': 0.9779115583649882,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (98, 'load'),
#    (108, 'eccentricity'),
#    (14, 'clustering_coef'),
#    (357, 'current_flow_closeness'),
#    (130, 'betweenness'),
#    (304, 'clustering_coef'),
#    (141, 'eccentricity'),
#    (76, 'load'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness'),
#    (85, 'clustering_coef'),
#    (145, 'load'),
#    (159, 'eigenvector'),
#    (268, 'betweenness'),
#    (203, 'clustering_coef'),
#    (154, 'harmonic'),
#    (80, 'subgraph'),
#    (65, 'load'),
#    (10, 'clustering_coef')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  29: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    282,
#    485,
#    507,
#    518,
#    654,
#    729,
#    756,
#    929,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295,
#    1510,
#    1615,
#    1798,
#    1919,
#    2013,
#    2122,
#    2164,
#    2400,
#    2446,
#    2471),
#   'cv_scores': array([0.98103619]),
#   'avg_score': 0.9810361886941029,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (98, 'load'),
#    (108, 'eccentricity'),
#    (14, 'clustering_coef'),
#    (357, 'current_flow_closeness'),
#    (130, 'betweenness'),
#    (304, 'clustering_coef'),
#    (141, 'eccentricity'),
#    (76, 'load'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness'),
#    (85, 'clustering_coef'),
#    (145, 'load'),
#    (159, 'eigenvector'),
#    (268, 'betweenness'),
#    (203, 'clustering_coef'),
#    (154, 'harmonic'),
#    (356, 'pagerank'),
#    (80, 'subgraph'),
#    (65, 'load'),
#    (10, 'clustering_coef')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  30: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    282,
#    485,
#    507,
#    518,
#    654,
#    729,
#    756,
#    929,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295,
#    1510,
#    1615,
#    1698,
#    1798,
#    1919,
#    2013,
#    2122,
#    2164,
#    2400,
#    2446,
#    2471),
#   'cv_scores': array([0.98338383]),
#   'avg_score': 0.9833838267281583,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (98, 'load'),
#    (108, 'eccentricity'),
#    (14, 'clustering_coef'),
#    (357, 'current_flow_closeness'),
#    (130, 'betweenness'),
#    (304, 'clustering_coef'),
#    (141, 'eccentricity'),
#    (76, 'load'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness'),
#    (85, 'clustering_coef'),
#    (145, 'load'),
#    (217, 'eccentricity'),
#    (159, 'eigenvector'),
#    (268, 'betweenness'),
#    (203, 'clustering_coef'),
#    (154, 'harmonic'),
#    (356, 'pagerank'),
#    (80, 'subgraph'),
#    (65, 'load'),
#    (10, 'clustering_coef')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  31: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    282,
#    485,
#    507,
#    518,
#    654,
#    729,
#    756,
#    929,
#    1025,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295,
#    1510,
#    1615,
#    1698,
#    1798,
#    1919,
#    2013,
#    2122,
#    2164,
#    2400,
#    2446,
#    2471),
#   'cv_scores': array([0.98559704]),
#   'avg_score': 0.9855970407365245,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (98, 'load'),
#    (108, 'eccentricity'),
#    (14, 'clustering_coef'),
#    (357, 'current_flow_closeness'),
#    (130, 'betweenness'),
#    (304, 'clustering_coef'),
#    (141, 'eccentricity'),
#    (76, 'load'),
#    (51, 'clustering_coef'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness'),
#    (85, 'clustering_coef'),
#    (145, 'load'),
#    (217, 'eccentricity'),
#    (159, 'eigenvector'),
#    (268, 'betweenness'),
#    (203, 'clustering_coef'),
#    (154, 'harmonic'),
#    (356, 'pagerank'),
#    (80, 'subgraph'),
#    (65, 'load'),
#    (10, 'clustering_coef')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  32: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    282,
#    485,
#    507,
#    518,
#    654,
#    729,
#    756,
#    929,
#    1025,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1295,
#    1510,
#    1615,
#    1698,
#    1798,
#    1851,
#    1919,
#    2013,
#    2122,
#    2164,
#    2400,
#    2446,
#    2471),
#   'cv_scores': array([0.98782028]),
#   'avg_score': 0.9878202772438066,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (98, 'load'),
#    (108, 'eccentricity'),
#    (14, 'clustering_coef'),
#    (357, 'current_flow_closeness'),
#    (130, 'betweenness'),
#    (304, 'clustering_coef'),
#    (141, 'eccentricity'),
#    (76, 'load'),
#    (51, 'clustering_coef'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (348, 'closeness'),
#    (85, 'clustering_coef'),
#    (145, 'load'),
#    (217, 'eccentricity'),
#    (159, 'eigenvector'),
#    (222, 'strength'),
#    (268, 'betweenness'),
#    (203, 'clustering_coef'),
#    (154, 'harmonic'),
#    (356, 'pagerank'),
#    (80, 'subgraph'),
#    (65, 'load'),
#    (10, 'clustering_coef')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  33: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    282,
#    485,
#    507,
#    518,
#    654,
#    729,
#    756,
#    929,
#    1025,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1281,
#    1295,
#    1510,
#    1615,
#    1698,
#    1798,
#    1851,
#    1919,
#    2013,
#    2122,
#    2164,
#    2400,
#    2446,
#    2471),
#   'cv_scores': array([0.98935874]),
#   'avg_score': 0.9893587399738453,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (98, 'load'),
#    (108, 'eccentricity'),
#    (14, 'clustering_coef'),
#    (357, 'current_flow_closeness'),
#    (130, 'betweenness'),
#    (304, 'clustering_coef'),
#    (141, 'eccentricity'),
#    (76, 'load'),
#    (51, 'clustering_coef'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (51, 'subgraph'),
#    (348, 'closeness'),
#    (85, 'clustering_coef'),
#    (145, 'load'),
#    (217, 'eccentricity'),
#    (159, 'eigenvector'),
#    (222, 'strength'),
#    (268, 'betweenness'),
#    (203, 'clustering_coef'),
#    (154, 'harmonic'),
#    (356, 'pagerank'),
#    (80, 'subgraph'),
#    (65, 'load'),
#    (10, 'clustering_coef')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  34: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    282,
#    485,
#    507,
#    518,
#    654,
#    729,
#    756,
#    929,
#    1025,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1281,
#    1295,
#    1510,
#    1615,
#    1698,
#    1798,
#    1851,
#    1878,
#    1919,
#    2013,
#    2122,
#    2164,
#    2400,
#    2446,
#    2471),
#   'cv_scores': array([0.99120639]),
#   'avg_score': 0.991206394464341,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (98, 'load'),
#    (108, 'eccentricity'),
#    (14, 'clustering_coef'),
#    (357, 'current_flow_closeness'),
#    (130, 'betweenness'),
#    (304, 'clustering_coef'),
#    (141, 'eccentricity'),
#    (76, 'load'),
#    (51, 'clustering_coef'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (51, 'subgraph'),
#    (348, 'closeness'),
#    (85, 'clustering_coef'),
#    (145, 'load'),
#    (217, 'eccentricity'),
#    (159, 'eigenvector'),
#    (222, 'strength'),
#    (314, 'current_flow_closeness'),
#    (268, 'betweenness'),
#    (203, 'clustering_coef'),
#    (154, 'harmonic'),
#    (356, 'pagerank'),
#    (80, 'subgraph'),
#    (65, 'load'),
#    (10, 'clustering_coef')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan},
#  35: {'feature_idx': (0,
#    2,
#    6,
#    90,
#    247,
#    282,
#    485,
#    507,
#    518,
#    654,
#    729,
#    756,
#    929,
#    1025,
#    1054,
#    1130,
#    1197,
#    1220,
#    1238,
#    1281,
#    1295,
#    1510,
#    1615,
#    1698,
#    1798,
#    1851,
#    1878,
#    1919,
#    1940,
#    2013,
#    2122,
#    2164,
#    2400,
#    2446,
#    2471),
#   'cv_scores': array([0.99219142]),
#   'avg_score': 0.9921914161248366,
#   'feature_names': ((239, 'closeness'),
#    (224, 'closeness'),
#    (87, 'strength'),
#    (101, 'betweenness'),
#    (68, 'strength'),
#    (98, 'load'),
#    (108, 'eccentricity'),
#    (14, 'clustering_coef'),
#    (357, 'current_flow_closeness'),
#    (130, 'betweenness'),
#    (304, 'clustering_coef'),
#    (141, 'eccentricity'),
#    (76, 'load'),
#    (51, 'clustering_coef'),
#    (281, 'subgraph'),
#    (211, 'clustering_coef'),
#    (180, 'clustering_coef'),
#    (160, 'closeness'),
#    (50, 'harmonic'),
#    (51, 'subgraph'),
#    (348, 'closeness'),
#    (85, 'clustering_coef'),
#    (145, 'load'),
#    (217, 'eccentricity'),
#    (159, 'eigenvector'),
#    (222, 'strength'),
#    (314, 'current_flow_closeness'),
#    (268, 'betweenness'),
#    (99, 'closeness'),
#    (203, 'clustering_coef'),
#    (154, 'harmonic'),
#    (356, 'pagerank'),
#    (80, 'subgraph'),
#    (65, 'load'),
#    (10, 'clustering_coef')),
#   'ci_bound': nan,
#   'std_dev': 0.0,
#   'std_err': nan}}

# %%
fisher_features_names_sfsLR    = list(sfsLinReg.k_feature_names_)
fisher_features_names_sfsLR    = [ffn for ffn in fisher_features_names_sfsLR if type(ffn)!=str]
fisher_features_nodes_sfsLR    = [ffn[0] for ffn in fisher_features_names_sfsLR]
fisher_features_measures_sfsLR = [ffn[1] for ffn in fisher_features_names_sfsLR]
fisher_features_measures_sfsLR.sort()
fisher_features_nodes_sfsLR.sort()
counter_measures_sfsLR=collections.Counter(fisher_features_measures_sfsLR)
counter_nodes_sfsLR=collections.Counter(fisher_features_nodes_sfsLR)

# %%
enodes_sfsLR = [np.array(counter_nodes_sfsLR.most_common(360)),
                'sfsLR-%d'%len(counter_nodes_sfsLR.most_common(360))]

# %%
fig, ax = plt.subplots(figsize=(20,5))
plt.scatter(*zip(*[(str(a[0]),a[1]) for a in counter_nodes_sfsLR.most_common(50)]))
plt.xticks(np.arange(0, len(set(fisher_features_nodes_sfsLR)), step=1))
plt.legend(['all','6'])
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:.0f}"))
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
plt.show()

fNodes_sfsLR=counter_nodes_sfsLR.most_common(50)
nd_sfsLR = [a[0] for a in fNodes_sfsLR]
ns_sfsLR = [a[1] for a in fNodes_sfsLR]
viz.brain_viz_nodes(nodes=nd_sfsLR,
                    title=
                    "\t%d Nodes:\n\t%s"%(len(nd_sfsLR),
                                         counter_nodes_sfsLR.most_common(360)),
                    method='2d',node_size = ns_sfsLR)
# Out:
# /home/alireza/Thesis/THSenv/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/alireza/Thesis/THSenv/lib/python3.6/site-packages/numpy/core/_methods.py:154: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# 	34 Nodes:
# 	[(51, 2), (10, 1), (14, 1), (50, 1), (65, 1), (68, 1), (76, 1), (80, 1), (85, 1), (87, 1), (98, 1), (99, 1), (101, 1), (108, 1), (130, 1), (141, 1), (145, 1), (154, 1), (159, 1), (160, 1), (180, 1), (203, 1), (211, 1), (217, 1), (222, 1), (224, 1), (239, 1), (268, 1), (281, 1), (304, 1), (314, 1), (348, 1), (356, 1), (357, 1)]

# %%
plt.figure(figsize=(20,5))
plt.scatter(*zip(*counter_measures_sfsLR.most_common(50)))
plt.xticks(np.arange(0, 14, step=1))
plt.show()
print(counter_measures_sfsLR.most_common(14))
# Out:
# [('clustering_coef', 8), ('closeness', 5), ('load', 4), ('betweenness', 3), ('eccentricity', 3), ('strength', 3), ('subgraph', 3), ('current_flow_closeness', 2), ('harmonic', 2), ('eigenvector', 1), ('pagerank', 1)]

# %% [markdown]
# Selecting effective nodes and measures based on FSF algorithm (linear regression classifier)

# %% [markdown]
# #### SVM

# %%
svc = svm.SVC(random_state=0, probability=True)
sfsSVC = SFS(svc, 
           k_features=17,
           forward=True, 
           floating=False, 
           verbose=2,
           scoring='accuracy',
           cv=0)

# %%
sfsSVC.fit(fisher_features_np, labels_np,tuple(fisher_features.columns))
sfsSVC.k_feature_names_
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 2497 out of 2497 | elapsed:   10.2s finished
#
# [2020-10-02 20:00:35] Features: 1/17 -- score: 0.5[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 2496 out of 2496 | elapsed:   10.0s finished
#
# [2020-10-02 20:00:45] Features: 2/17 -- score: 0.59375[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 2495 out of 2495 | elapsed:   10.8s finished
#
# [2020-10-02 20:00:56] Features: 3/17 -- score: 0.6770833333333334[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 2494 out of 2494 | elapsed:   10.6s finished
#
# [2020-10-02 20:01:06] Features: 4/17 -- score: 0.71875[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 2493 out of 2493 | elapsed:   11.3s finished
#
# [2020-10-02 20:01:18] Features: 5/17 -- score: 0.7395833333333334[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 2492 out of 2492 | elapsed:   11.6s finished
#
# [2020-10-02 20:01:29] Features: 6/17 -- score: 0.7708333333333334[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 2491 out of 2491 | elapsed:   10.6s finished
#
# [2020-10-02 20:01:40] Features: 7/17 -- score: 0.8020833333333334[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 2490 out of 2490 | elapsed:   10.5s finished
#
# [2020-10-02 20:01:51] Features: 8/17 -- score: 0.8229166666666666[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 2489 out of 2489 | elapsed:   12.2s finished
#
# [2020-10-02 20:02:03] Features: 9/17 -- score: 0.8541666666666666[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 2488 out of 2488 | elapsed:   11.2s finished
#
# [2020-10-02 20:02:14] Features: 10/17 -- score: 0.8854166666666666[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 2487 out of 2487 | elapsed:   11.3s finished
#
# [2020-10-02 20:02:26] Features: 11/17 -- score: 0.9166666666666666[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 2486 out of 2486 | elapsed:   11.4s finished
#
# [2020-10-02 20:02:37] Features: 12/17 -- score: 0.9270833333333334[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 2485 out of 2485 | elapsed:   13.3s finished
#
# [2020-10-02 20:02:51] Features: 13/17 -- score: 0.9479166666666666[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 2484 out of 2484 | elapsed:   13.4s finished
#
# [2020-10-02 20:03:04] Features: 14/17 -- score: 0.9479166666666666[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 2483 out of 2483 | elapsed:   12.9s finished
#
# [2020-10-02 20:03:17] Features: 15/17 -- score: 0.9583333333333334[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 2482 out of 2482 | elapsed:   13.0s finished
#
# [2020-10-02 20:03:30] Features: 16/17 -- score: 0.9583333333333334[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 2481 out of 2481 | elapsed:   13.4s finished
#
# [2020-10-02 20:03:44] Features: 17/17 -- score: 0.96875
# ((239, 'closeness'),
#  (93, 'strength'),
#  (59, 'pagerank'),
#  (352, 'load'),
#  (25, 'strength'),
#  (125, 'eigenvector'),
#  (159, 'closeness'),
#  (335, 'betweenness'),
#  (125, 'degree'),
#  (238, 'katz'),
#  (72, 'subgraph'),
#  (76, 'katz'),
#  (291, 'clustering_coef'),
#  (198, 'pagerank'),
#  (173, 'harmonic'),
#  (40, 'eigenvector'),
#  (220, 'harmonic'))

# %%
figSVC = plot_sfs(sfsSVC.get_metric_dict(), kind='std_dev')
plt.title('Sequential Forward Selection (w. StdErr)')
plt.grid()
plt.show()
# Out:
# /home/alireza/Thesis/THSenv/lib/python3.6/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/alireza/Thesis/THSenv/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
sfsSVC.subsets_
# Out:
# {1: {'feature_idx': (187,),
#   'cv_scores': array([0.5]),
#   'avg_score': 0.5,
#   'feature_names': ((352, 'load'),)},
#  2: {'feature_idx': (187, 930),
#   'cv_scores': array([0.59375]),
#   'avg_score': 0.59375,
#   'feature_names': ((352, 'load'), (291, 'clustering_coef'))},
#  3: {'feature_idx': (0, 187, 930),
#   'cv_scores': array([0.67708333]),
#   'avg_score': 0.6770833333333334,
#   'feature_names': ((239, 'closeness'),
#    (352, 'load'),
#    (291, 'clustering_coef'))},
#  4: {'feature_idx': (0, 187, 371, 930),
#   'cv_scores': array([0.71875]),
#   'avg_score': 0.71875,
#   'feature_names': ((239, 'closeness'),
#    (352, 'load'),
#    (25, 'strength'),
#    (291, 'clustering_coef'))},
#  5: {'feature_idx': (0, 187, 371, 906, 930),
#   'cv_scores': array([0.73958333]),
#   'avg_score': 0.7395833333333334,
#   'feature_names': ((239, 'closeness'),
#    (352, 'load'),
#    (25, 'strength'),
#    (76, 'katz'),
#    (291, 'clustering_coef'))},
#  6: {'feature_idx': (0, 156, 187, 371, 906, 930),
#   'cv_scores': array([0.77083333]),
#   'avg_score': 0.7708333333333334,
#   'feature_names': ((239, 'closeness'),
#    (93, 'strength'),
#    (352, 'load'),
#    (25, 'strength'),
#    (76, 'katz'),
#    (291, 'clustering_coef'))},
#  7: {'feature_idx': (0, 156, 187, 371, 493, 906, 930),
#   'cv_scores': array([0.80208333]),
#   'avg_score': 0.8020833333333334,
#   'feature_names': ((239, 'closeness'),
#    (93, 'strength'),
#    (352, 'load'),
#    (25, 'strength'),
#    (125, 'eigenvector'),
#    (76, 'katz'),
#    (291, 'clustering_coef'))},
#  8: {'feature_idx': (0, 156, 187, 371, 493, 692, 906, 930),
#   'cv_scores': array([0.82291667]),
#   'avg_score': 0.8229166666666666,
#   'feature_names': ((239, 'closeness'),
#    (93, 'strength'),
#    (352, 'load'),
#    (25, 'strength'),
#    (125, 'eigenvector'),
#    (238, 'katz'),
#    (76, 'katz'),
#    (291, 'clustering_coef'))},
#  9: {'feature_idx': (0, 156, 187, 371, 493, 692, 708, 906, 930),
#   'cv_scores': array([0.85416667]),
#   'avg_score': 0.8541666666666666,
#   'feature_names': ((239, 'closeness'),
#    (93, 'strength'),
#    (352, 'load'),
#    (25, 'strength'),
#    (125, 'eigenvector'),
#    (238, 'katz'),
#    (72, 'subgraph'),
#    (76, 'katz'),
#    (291, 'clustering_coef'))},
#  10: {'feature_idx': (0, 156, 187, 371, 493, 692, 708, 906, 930, 1074),
#   'cv_scores': array([0.88541667]),
#   'avg_score': 0.8854166666666666,
#   'feature_names': ((239, 'closeness'),
#    (93, 'strength'),
#    (352, 'load'),
#    (25, 'strength'),
#    (125, 'eigenvector'),
#    (238, 'katz'),
#    (72, 'subgraph'),
#    (76, 'katz'),
#    (291, 'clustering_coef'),
#    (173, 'harmonic'))},
#  11: {'feature_idx': (0, 156, 187, 371, 493, 692, 708, 906, 930, 1012, 1074),
#   'cv_scores': array([0.91666667]),
#   'avg_score': 0.9166666666666666,
#   'feature_names': ((239, 'closeness'),
#    (93, 'strength'),
#    (352, 'load'),
#    (25, 'strength'),
#    (125, 'eigenvector'),
#    (238, 'katz'),
#    (72, 'subgraph'),
#    (76, 'katz'),
#    (291, 'clustering_coef'),
#    (198, 'pagerank'),
#    (173, 'harmonic'))},
#  12: {'feature_idx': (0,
#    156,
#    167,
#    187,
#    371,
#    493,
#    692,
#    708,
#    906,
#    930,
#    1012,
#    1074),
#   'cv_scores': array([0.92708333]),
#   'avg_score': 0.9270833333333334,
#   'feature_names': ((239, 'closeness'),
#    (93, 'strength'),
#    (59, 'pagerank'),
#    (352, 'load'),
#    (25, 'strength'),
#    (125, 'eigenvector'),
#    (238, 'katz'),
#    (72, 'subgraph'),
#    (76, 'katz'),
#    (291, 'clustering_coef'),
#    (198, 'pagerank'),
#    (173, 'harmonic'))},
#  13: {'feature_idx': (0,
#    156,
#    167,
#    187,
#    371,
#    493,
#    533,
#    692,
#    708,
#    906,
#    930,
#    1012,
#    1074),
#   'cv_scores': array([0.94791667]),
#   'avg_score': 0.9479166666666666,
#   'feature_names': ((239, 'closeness'),
#    (93, 'strength'),
#    (59, 'pagerank'),
#    (352, 'load'),
#    (25, 'strength'),
#    (125, 'eigenvector'),
#    (335, 'betweenness'),
#    (238, 'katz'),
#    (72, 'subgraph'),
#    (76, 'katz'),
#    (291, 'clustering_coef'),
#    (198, 'pagerank'),
#    (173, 'harmonic'))},
#  14: {'feature_idx': (0,
#    156,
#    167,
#    187,
#    371,
#    493,
#    533,
#    621,
#    692,
#    708,
#    906,
#    930,
#    1012,
#    1074),
#   'cv_scores': array([0.94791667]),
#   'avg_score': 0.9479166666666666,
#   'feature_names': ((239, 'closeness'),
#    (93, 'strength'),
#    (59, 'pagerank'),
#    (352, 'load'),
#    (25, 'strength'),
#    (125, 'eigenvector'),
#    (335, 'betweenness'),
#    (125, 'degree'),
#    (238, 'katz'),
#    (72, 'subgraph'),
#    (76, 'katz'),
#    (291, 'clustering_coef'),
#    (198, 'pagerank'),
#    (173, 'harmonic'))},
#  15: {'feature_idx': (0,
#    156,
#    167,
#    187,
#    371,
#    493,
#    533,
#    621,
#    692,
#    708,
#    906,
#    930,
#    1012,
#    1074,
#    2313),
#   'cv_scores': array([0.95833333]),
#   'avg_score': 0.9583333333333334,
#   'feature_names': ((239, 'closeness'),
#    (93, 'strength'),
#    (59, 'pagerank'),
#    (352, 'load'),
#    (25, 'strength'),
#    (125, 'eigenvector'),
#    (335, 'betweenness'),
#    (125, 'degree'),
#    (238, 'katz'),
#    (72, 'subgraph'),
#    (76, 'katz'),
#    (291, 'clustering_coef'),
#    (198, 'pagerank'),
#    (173, 'harmonic'),
#    (220, 'harmonic'))},
#  16: {'feature_idx': (0,
#    156,
#    167,
#    187,
#    371,
#    493,
#    533,
#    621,
#    692,
#    708,
#    906,
#    930,
#    1012,
#    1074,
#    1840,
#    2313),
#   'cv_scores': array([0.95833333]),
#   'avg_score': 0.9583333333333334,
#   'feature_names': ((239, 'closeness'),
#    (93, 'strength'),
#    (59, 'pagerank'),
#    (352, 'load'),
#    (25, 'strength'),
#    (125, 'eigenvector'),
#    (335, 'betweenness'),
#    (125, 'degree'),
#    (238, 'katz'),
#    (72, 'subgraph'),
#    (76, 'katz'),
#    (291, 'clustering_coef'),
#    (198, 'pagerank'),
#    (173, 'harmonic'),
#    (40, 'eigenvector'),
#    (220, 'harmonic'))},
#  17: {'feature_idx': (0,
#    156,
#    167,
#    187,
#    371,
#    493,
#    504,
#    533,
#    621,
#    692,
#    708,
#    906,
#    930,
#    1012,
#    1074,
#    1840,
#    2313),
#   'cv_scores': array([0.96875]),
#   'avg_score': 0.96875,
#   'feature_names': ((239, 'closeness'),
#    (93, 'strength'),
#    (59, 'pagerank'),
#    (352, 'load'),
#    (25, 'strength'),
#    (125, 'eigenvector'),
#    (159, 'closeness'),
#    (335, 'betweenness'),
#    (125, 'degree'),
#    (238, 'katz'),
#    (72, 'subgraph'),
#    (76, 'katz'),
#    (291, 'clustering_coef'),
#    (198, 'pagerank'),
#    (173, 'harmonic'),
#    (40, 'eigenvector'),
#    (220, 'harmonic'))}}

# %%
fisher_features_names_sfsSVM = list(sfsSVC.k_feature_names_)
fisher_features_names_sfsSVM = [ffn for ffn in fisher_features_names_sfsSVM if type(ffn)!=str]
fisher_features_nodes_sfsSVM = [ffn[0] for ffn in fisher_features_names_sfsSVM]
fisher_features_measures_sfsSVM = [ffn[1] for ffn in fisher_features_names_sfsSVM]
fisher_features_measures_sfsSVM.sort()
fisher_features_nodes_sfsSVM.sort()
counter_measures_sfsSVM=collections.Counter(fisher_features_measures_sfsSVM)
counter_nodes_sfsSVM=collections.Counter(fisher_features_nodes_sfsSVM)

# %%
enodes_sfsSVM = [np.array(counter_nodes_sfsSVM.most_common(360)),
                'sfsSVM-%d'%len(counter_nodes_sfsSVM.most_common(360))]

# %%
plt.figure(figsize=(20,5))
fig, ax = plt.subplots(figsize=(20,5))
plt.scatter(*zip(*[(str(a[0]),a[1]) for a in counter_nodes_sfsSVM.most_common(50)]))
plt.xticks(np.arange(0, len(set(fisher_features_nodes_sfsSVM)), step=1))
plt.legend(['all','6'])
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:.0f}"))
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
plt.show()

fNodes_sfsSVM=counter_nodes_sfsSVM.most_common(50)
nd_sfsSVM = [a[0] for a in fNodes_sfsSVM]
ns_sfsSVM = [a[1] for a in fNodes_sfsSVM]
viz.brain_viz_nodes(nodes=nd_sfsSVM,
                    title="\t%d Nodes:\n\t%s"
                    %(len(nd_sfsSVM),counter_nodes_sfsSVM.most_common(360)), 
                      method='2d',node_size = ns_sfsSVM)
# Out:
# /home/alireza/Thesis/THSenv/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/alireza/Thesis/THSenv/lib/python3.6/site-packages/numpy/core/_methods.py:154: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# 	16 Nodes:
# 	[(125, 2), (25, 1), (40, 1), (59, 1), (72, 1), (76, 1), (93, 1), (159, 1), (173, 1), (198, 1), (220, 1), (238, 1), (239, 1), (291, 1), (335, 1), (352, 1)]

# %%
plt.figure(figsize=(20,5))
plt.scatter(*zip(*counter_measures_sfsSVM.most_common(50)))
plt.xticks(np.arange(0, 14, step=1))
plt.show()
print(counter_measures_sfsSVM.most_common(14))
# Out:
# [('closeness', 2), ('eigenvector', 2), ('harmonic', 2), ('katz', 2), ('pagerank', 2), ('strength', 2), ('betweenness', 1), ('clustering_coef', 1), ('degree', 1), ('load', 1), ('subgraph', 1)]

# %% [markdown]
# ### Link Selection Based on Correlation Matrices

# %%
cols = subjects_list[subjects_groups[0]].copy()
sep=[len(subjects_list[subjects_groups[0]])]
for i in range(1,len(subjects_groups)):
    cols.extend(subjects_list[subjects_groups[i]])
    sep.append(len(subjects_list[subjects_groups[i]]) + sep[i-1])
sep.insert(0,0)

# %%
dfM = {}
for i in range(len(subjects_groups)):
    for s in cols[sep[i]:sep[i+1]]:
        M = gla.read_M(s,ds,ct)
        df = pd.DataFrame(data=M, index=range(np.shape(M)[0]), columns=range(np.shape(M)[0]))
        df = df.drop([119],axis=1)
        df = df.drop([119],axis=0)
        df = df.stack().to_frame()
        try:
            dfM[subjects_groups[i]] = pd.concat([dfM[subjects_groups[i]],df],axis=1)
        except KeyError:
            dfM[subjects_groups[i]] = df.copy()
    try:
        dfM['all'] = pd.concat([dfM['all'],dfM[subjects_groups[i]]],axis=1)
    except KeyError:
        dfM['all'] = dfM[subjects_groups[i]].copy()

# %% [markdown]
# #### Fisher

# %%
score = fisher_score.fisher_score(dfM['all'].T.values, labels_np)
idx   = fisher_score.feature_ranking(score)

# %%
fisher_features260       = dfM['all'].T.iloc[:, idx[:520]]
fisher_features_names260 = list(fisher_features260.T.index) 
fisher_features_1260     = [ffn[0] for ffn in fisher_features_names260]
fisher_features_nodes260 = [ffn[1] for ffn in fisher_features_names260]
fisher_features_nodes260.extend(fisher_features_1260)
fisher_features_nodes260.sort()
counter_nodes260=collections.Counter(fisher_features_nodes260)

# %%
a2 = 15
fig, ax = plt.subplots(figsize=(30,5))
plt.scatter(*zip(*[(str(a[0]),a[1]) for a in counter_nodes260.most_common(len(set(fisher_features_nodes260)))]))
plt.scatter(*zip(*[(str(a[0]),a[1]) for a in counter_nodes260.most_common(a2)]))

plt.xticks(np.arange(0, len(set(fisher_features_nodes260)), step=1))
plt.legend(['all',a2])
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:.0f}"))
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
plt.show()

fNodes2602=counter_nodes260.most_common(a2)
nd2602 = [a[0] for a in fNodes2602]
ns2602 = [a[1] for a in fNodes2602]
viz.brain_viz_nodes(nodes=nd2602,title="\t%s Links:\n\t%s"%(a2,counter_nodes260.most_common(a2)),method='2d',node_size = ns2602)
plt.show()
# Out:
# /home/alireza/Thesis/THSenv/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/alireza/Thesis/THSenv/lib/python3.6/site-packages/numpy/core/_methods.py:154: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# 	15 Links:
# 	[(264, 24), (338, 24), (348, 22), (156, 20), (272, 20), (140, 18), (254, 18), (290, 18), (134, 16), (168, 16), (252, 16), (225, 14), (142, 12), (258, 12), (337, 12)]

# %%
fisher_features_links200 = dfM['all'].T.iloc[:, idx[:200]]
fisher_features_names_links200 = list(fisher_features_links200.T.index) 
fisher_features_names_links200
# Out:
# [(124, 65),
#  (65, 124),
#  (320, 140),
#  (140, 320),
#  (252, 338),
#  (338, 252),
#  (21, 156),
#  (156, 21),
#  (261, 264),
#  (264, 261),
#  (15, 283),
#  (283, 15),
#  (272, 314),
#  (314, 272),
#  (67, 252),
#  (252, 67),
#  (34, 300),
#  (300, 34),
#  (350, 290),
#  (290, 350),
#  (245, 292),
#  (292, 245),
#  (35, 225),
#  (225, 35),
#  (293, 134),
#  (134, 293),
#  (208, 338),
#  (338, 208),
#  (272, 219),
#  (219, 272),
#  (156, 269),
#  (269, 156),
#  (74, 2),
#  (2, 74),
#  (169, 348),
#  (348, 169),
#  (85, 17),
#  (17, 85),
#  (272, 77),
#  (77, 272),
#  (184, 140),
#  (140, 184),
#  (337, 250),
#  (250, 337),
#  (264, 83),
#  (83, 264),
#  (208, 150),
#  (150, 208),
#  (212, 318),
#  (318, 212),
#  (158, 152),
#  (152, 158),
#  (250, 47),
#  (47, 250),
#  (29, 89),
#  (89, 29),
#  (272, 355),
#  (355, 272),
#  (221, 290),
#  (290, 221),
#  (269, 336),
#  (336, 269),
#  (64, 254),
#  (254, 64),
#  (272, 356),
#  (356, 272),
#  (1, 142),
#  (142, 1),
#  (245, 290),
#  (290, 245),
#  (264, 169),
#  (169, 264),
#  (288, 278),
#  (278, 288),
#  (240, 348),
#  (348, 240),
#  (335, 157),
#  (157, 335),
#  (142, 319),
#  (319, 142),
#  (32, 332),
#  (332, 32),
#  (63, 348),
#  (348, 63),
#  (246, 338),
#  (338, 246),
#  (359, 196),
#  (196, 359),
#  (260, 197),
#  (197, 260),
#  (185, 140),
#  (140, 185),
#  (226, 290),
#  (290, 226),
#  (332, 13),
#  (13, 332),
#  (32, 339),
#  (339, 32),
#  (335, 252),
#  (252, 335),
#  (272, 309),
#  (309, 272),
#  (129, 163),
#  (163, 129),
#  (60, 341),
#  (341, 60),
#  (36, 141),
#  (141, 36),
#  (316, 258),
#  (258, 316),
#  (156, 85),
#  (85, 156),
#  (316, 134),
#  (134, 316),
#  (254, 324),
#  (324, 254),
#  (84, 90),
#  (90, 84),
#  (313, 272),
#  (272, 313),
#  (79, 135),
#  (135, 79),
#  (208, 212),
#  (212, 208),
#  (215, 173),
#  (173, 215),
#  (315, 85),
#  (85, 315),
#  (350, 270),
#  (270, 350),
#  (63, 254),
#  (254, 63),
#  (292, 63),
#  (63, 292),
#  (314, 299),
#  (299, 314),
#  (254, 182),
#  (182, 254),
#  (263, 338),
#  (338, 263),
#  (230, 169),
#  (169, 230),
#  (74, 229),
#  (229, 74),
#  (168, 296),
#  (296, 168),
#  (142, 36),
#  (36, 142),
#  (208, 32),
#  (32, 208),
#  (31, 40),
#  (40, 31),
#  (277, 200),
#  (200, 277),
#  (164, 0),
#  (0, 164),
#  (14, 70),
#  (70, 14),
#  (46, 134),
#  (134, 46),
#  (80, 252),
#  (252, 80),
#  (348, 245),
#  (245, 348),
#  (138, 195),
#  (195, 138),
#  (60, 348),
#  (348, 60),
#  (264, 257),
#  (257, 264),
#  (354, 272),
#  (272, 354),
#  (338, 13),
#  (13, 338),
#  (97, 272),
#  (272, 97),
#  (348, 64),
#  (64, 348),
#  (132, 147),
#  (147, 132),
#  (264, 107),
#  (107, 264),
#  (255, 156),
#  (156, 255),
#  (134, 327),
#  (327, 134),
#  (157, 55),
#  (55, 157),
#  (336, 137),
#  (137, 336),
#  (338, 341),
#  (341, 338),
#  (142, 140),
#  (140, 142),
#  (168, 221),
#  (221, 168),
#  (278, 293),
#  (293, 278),
#  (34, 264),
#  (264, 34)]

# %%
elinks_200 = [np.array(fisher_features_names_links200),
              'links-fisher-%d'
              # %int(len(fisher_features_names_links200)/2)]

# %%
M = np.zeros((360,360))
for i in fisher_features_names_links200:
    M[i[0],i[1]]=1
viz.brain_viz_from_path(cm = M ,
                        title = 'Link Selection Based on Correlation Matrices',
                        density = 1, method = '2d')
# Out:
# Link Selection Based on Correlation Matrices

# %% [markdown]
# #### PCA

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
x = StandardScaler().fit_transform(dfM['all'].T)
pca = PCA().fit(x)
#Plotting the Cumulative Summation of the Explained Variance
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('Pulsar Dataset Explained Variance')
plt.show()

# %% [markdown]
# ### Save

# %%
os.system('mkdir -p %s/data/07_features/tm-%s/corr-%s/ds-%s'%(rootdir,tm,ct,ds))

np.save("%s/data/07_features/tm-%s/corr-%s/ds-%s/method-%s_ds-%s_corr-%s-%s_tm-%s"
            %(rootdir,tm,ct,ds,enodes4_top[1],ds,ct,sgn,tm), enodes4_top[0])
        
np.save("%s/data/07_features/tm-%s/corr-%s/ds-%s/method-%s_ds-%s_corr-%s-%s_tm-%s"
            %(rootdir,tm,ct,ds,enodes4[1],ds,ct,sgn,tm), enodes4[0])
        
np.save("%s/data/07_features/tm-%s/corr-%s/ds-%s/method-%s_ds-%s_corr-%s-%s_tm-%s"
            %(rootdir,tm,ct,ds,enodes_sfsLR[1],ds,ct,sgn,tm), enodes_sfsLR[0])
        
np.save("%s/data/07_features/tm-%s/corr-%s/ds-%s/method-%s_ds-%s_corr-%s-%s_tm-%s"
            %(rootdir,tm,ct,ds,enodes_sfsSVM[1],ds,ct,sgn,tm), enodes_sfsSVM[0])

np.save("%s/data/07_features/tm-%s/corr-%s/ds-%s/method-%s_ds-%s_corr-%s-%s_tm-%s"
            %(rootdir,tm,ct,ds,elinks_200[1],ds,ct,sgn,tm), elinks_200[0])

# %% [markdown]
# #### Save the notebook

# %%
os.system("mkdir -p %s/docs/feature_selection"%(rootdir))
# Out:
# 0

# %%
os.system("cp %s/notebooks/08_feature_selection.ipynb %s/docs/feature_selection/%s-%s-corr_ds-%s_tm-%s.ipynb"
          %(rootdir,rootdir,ct,sgn,ds,tm))
# Out:
# 0
